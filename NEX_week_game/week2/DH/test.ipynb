# %%
from math import prod
from Crypto.Util.number import *
while 1:
    s = [getPrime(32) for _ in range(64)]
    p = 2*prod(s) + 1
    if isPrime(p):
        print(p)
        break
# Out:
# ...

# %%
from sage.all import *
p = ...
C = ...
A_pub = ...
B_pub = ...

A_pri = discrete_log(Mod(A_pub,p),Mod(2,p))
B_pri = discrete_log(Mod(B_pub,p),Mod(2,p))

key = pow(B_pub,A_pri,p)
m = C*inverse_mod(key,p) % p
print(long_to_bytes(int(m)))
# Out:
# /tmp/ipykernel_9910/3963385799.py:7: RuntimeWarning: cypari2 leaked 13678024 bytes on the PARI stack
#   A_pri = discrete_log(Mod(A_pub,p),Mod(2,p))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_9910/3963385799.py in <module>
#       5 B_pub = [0;...
#       6
# ----> 7 A_pri = discrete_log(Mod(A_pub,p),Mod(2,p))
#       8 B_pri = discrete_log(Mod(B_pub,p),Mod(2,p))
#       9
#
# /usr/lib/python3/dist-packages/sage/groups/generic.py in discrete_log(a, base, ord, bounds, operation, identity, inverse, op)
#     795         if operation in multiplication_names:
#     796             try:
# --> 797                 ord = base.multiplicative_order()
#     798             except Exception:
#     799                 ord = base.order()
#
# ...
